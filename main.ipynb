# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# c:\Users\User\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\User\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# c:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Configurar opções de exibição do pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# %%
# leitura dos dados

categories = pd.read_csv('data/categories.csv', delimiter=';') 
customers = pd.read_csv('data/customers.csv', delimiter=';')
employee_territories = pd.read_csv('data/employee_territories.csv', delimiter=';') 
employees = pd.read_csv('data/employees.csv', delimiter=';')
order_details = pd.read_csv('data/order_details.csv', delimiter=';') 
orders = pd.read_csv('data/orders.csv', delimiter=';') 
products = pd.read_csv('data/products.csv', delimiter=';') 
region = pd.read_csv('data/region.csv', delimiter=';')
shippers = pd.read_csv('data/shippers.csv', delimiter=';') 
suppliers = pd.read_csv('data/suppliers.csv', delimiter=';') 
territories = pd.read_csv('data/territories.csv', delimiter=';')
us_states =  pd.read_csv('data/us_states.csv', delimiter=';')

# %%
# mostrar tabelas para analisar o que pode ser necessário  na limpeza e transformação dos dados
from IPython.display import display

# Exibir tabelas com os 5 primeiros
print("Categories")
display(categories.head())
print("\nCustomers")
display(customers.head())
print("\nEmployee Territories")
display(employee_territories.head())
print("\nEmployees")
display(employees.head())
print("\nOrder Details")
display(order_details.head())
print("\nOrders")
display(orders.head())
print("\nProducts")
display(products.head())
print("\nRegion")
display(region.head())
print("\nShippers")
display(shippers.head())
print("\nSuppliers")
display(suppliers.head())
print("\nTerritories")
display(territories.head())
print("\nUS States")
display(us_states.head())
# Out:
# Categories
#    category_id   category_name                                        description picture
# 0            1       Beverages        Soft drinks, coffees, teas, beers, and ales      \x
# 1            2      Condiments  Sweet and savory sauces, relishes, spreads, an...      \x
# 2            3     Confections                Desserts, candies, and sweet breads      \x
# 3            4  Dairy Products                                            Cheeses      \x
# 4            5  Grains/Cereals                Breads, crackers, pasta, and cereal      \x
# Customers
#   customer_id                        company_name        contact_name         contact_title                        address         city region postal_code  country           phone             fax
# 0       ALFKI                 Alfreds Futterkiste        Maria Anders  Sales Representative                  Obere Str. 57       Berlin    NaN       12209  Germany     030-0074321     030-0076545
# 1       ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo                 Owner  Avda. de la Constitución 2222  México D.F.    NaN       05021   Mexico    (5) 555-4729    (5) 555-3745
# 2       ANTON             Antonio Moreno Taquería      Antonio Moreno                 Owner                Mataderos  2312  México D.F.    NaN       05023   Mexico    (5) 555-3932             NaN
# 3       AROUT                     Around the Horn        Thomas Hardy  Sales Representative                120 Hanover Sq.       London    NaN     WA1 1DP       UK  (171) 555-7788  (171) 555-6750
# 4       BERGS                  Berglunds snabbköp  Christina Berglund   Order Administrator                Berguvsvägen  8        Luleå    NaN    S-958 22   Sweden   0921-12 34 65   0921-12 34 67
# Employee Territories
#    employee_id  territory_id
# 0            1          6897
# 1            1         19713
# 2            2          1581
# 3            2          1730
# 4            2          1833
# Employees
#    employee_id  last_name first_name                  title title_of_courtesy  birth_date   hire_date                      address      city region postal_code country      home_phone  extension photo                                              notes  reports_to                              photo_path
# 0            1    Davolio      Nancy   Sales Representative               Ms.  1948-12-08  1992-05-01  507 - 20th Ave. E.\nApt. 2A   Seattle     WA       98122     USA  (206) 555-9857       5467    \x  Education includes a BA in psychology from Col...         2.0    http://accweb/emmployees/davolio.bmp
# 1            2     Fuller     Andrew  Vice President, Sales               Dr.  1952-02-19  1992-08-14           908 W. Capital Way    Tacoma     WA       98401     USA  (206) 555-9482       3457    \x  Andrew received his BTS commercial in 1974 and...         NaN     http://accweb/emmployees/fuller.bmp
# 2            3  Leverling      Janet   Sales Representative               Ms.  1963-08-30  1992-04-01           722 Moss Bay Blvd.  Kirkland     WA       98033     USA  (206) 555-3412       3355    \x  Janet has a BS degree in chemistry from Boston...         2.0  http://accweb/emmployees/leverling.bmp
# 3            4    Peacock   Margaret   Sales Representative              Mrs.  1937-09-19  1993-05-03         4110 Old Redmond Rd.   Redmond     WA       98052     USA  (206) 555-8122       5176    \x  Margaret holds a BA in English literature from...         2.0    http://accweb/emmployees/peacock.bmp
# 4            5   Buchanan     Steven          Sales Manager               Mr.  1955-03-04  1993-10-17              14 Garrett Hill    London    NaN     SW1 8JR      UK   (71) 555-4848       3453    \x  Steven Buchanan graduated from St. Andrews Uni...         2.0   http://accweb/emmployees/buchanan.bmp
# Order Details
#    order_id  product_id  unit_price  quantity  discount
# 0     10248          11        14.0        12       0.0
# 1     10248          42         9.8        10       0.0
# 2     10248          72        34.8         5       0.0
# 3     10249          14        18.6         9       0.0
# 4     10249          51        42.4        40       0.0
# Orders
#    order_id customer_id  employee_id  order_date required_date shipped_date  ship_via  freight                  ship_name          ship_address       ship_city ship_region ship_postal_code ship_country
# 0     10248       VINET            5  1996-07-04    1996-08-01   1996-07-16         3    32.38  Vins et alcools Chevalier    59 rue de l'Abbaye           Reims         NaN            51100       France
# 1     10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10         1    11.61         Toms Spezialitäten         Luisenstr. 48         Münster         NaN            44087      Germany
# 2     10250       HANAR            4  1996-07-08    1996-08-05   1996-07-12         2    65.83              Hanari Carnes       Rua do Paço, 67  Rio de Janeiro          RJ        05454-876       Brazil
# 3     10251       VICTE            3  1996-07-08    1996-08-05   1996-07-15         1    41.34       Victuailles en stock    2, rue du Commerce            Lyon         NaN            69004       France
# 4     10252       SUPRD            4  1996-07-09    1996-08-06   1996-07-11         2    51.30           Suprêmes délices  Boulevard Tirou, 255       Charleroi         NaN           B-6000      Belgium
# Products
#    product_id                  product_name  supplier_id  category_id    quantity_per_unit  unit_price  units_in_stock  units_on_order  reorder_level  discontinued
# 0           1                          Chai            8            1   10 boxes x 30 bags       18.00              39               0             10             1
# 1           2                         Chang            1            1   24 - 12 oz bottles       19.00              17              40             25             1
# 2           3                 Aniseed Syrup            1            2  12 - 550 ml bottles       10.00              13              70             25             0
# 3           4  Chef Anton's Cajun Seasoning            2            2       48 - 6 oz jars       22.00              53               0              0             0
# 4           5        Chef Anton's Gumbo Mix            2            2             36 boxes       21.35               0               0              0             1
# Region
#    region_id region_description
# 0          1            Eastern
# 1          2            Western
# 2          3           Northern
# 3          4           Southern
# Shippers
#    shipper_id       company_name           phone
# 0           1     Speedy Express  (503) 555-9831
# 1           2     United Package  (503) 555-3199
# 2           3   Federal Shipping  (503) 555-9931
# 3           4  Alliance Shippers  1-800-222-0451
# 4           5                UPS  1-800-782-7892
# Suppliers
#    supplier_id                        company_name                contact_name         contact_title                    address         city    region postal_code country           phone             fax     homepage
# 0            1                      Exotic Liquids            Charlotte Cooper    Purchasing Manager             49 Gilbert St.       London       NaN     EC1 4SD      UK  (171) 555-2222             NaN          NaN
# 1            2          New Orleans Cajun Delights               Shelley Burke   Order Administrator             P.O. Box 78934  New Orleans        LA       70117     USA  (100) 555-4822             NaN  #CAJUN.HTM#
# 2            3           Grandma Kelly's Homestead               Regina Murphy  Sales Representative             707 Oxford Rd.    Ann Arbor        MI       48104     USA  (313) 555-5735  (313) 555-3349          NaN
# 3            4                       Tokyo Traders                Yoshi Nagase     Marketing Manager  9-8 Sekimai Musashino-shi        Tokyo       NaN         100   Japan  (03) 3555-5011             NaN          NaN
# 4            5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra  Export Administrator          Calle del Rosal 4       Oviedo  Asturias       33007   Spain  (98) 598 76 54             NaN          NaN
# Territories
#    territory_id territory_description  region_id
# 0          1581              Westboro          1
# 1          1730               Bedford          1
# 2          1833             Georgetow          1
# 3          2116                Boston          1
# 4          2139             Cambridge          1
# US States
#    state_id  state_name state_abbr state_region
# 0         1     Alabama         AL        south
# 1         2      Alaska         AK        north
# 2         3     Arizona         AZ         west
# 3         4    Arkansas         AR        south
# 4         5  California         CA         west

# %%
#Limpeza e Transformação dos Dados

# 1. Orders
# 2. Order_Details
# 3. Products

# %%
# Transformação de tipos de dados
orders['order_date'] = pd.to_datetime(orders['order_date'])
orders['required_date'] = pd.to_datetime(orders['required_date'])
orders['shipped_date'] = pd.to_datetime(orders['shipped_date'])

order_details['unit_price'] = order_details['unit_price'].astype(float)
order_details['quantity'] = order_details['quantity'].astype(int)
order_details['discount'] = order_details['discount'].astype(float)

products['unit_price'] = products['unit_price'].astype(float)
products['units_in_stock'] = products['units_in_stock'].astype(int)
products['units_on_order'] = products['units_on_order'].astype(int)
products['reorder_level'] = products['reorder_level'].astype(int)
products['discontinued'] = products['discontinued'].astype(bool)

# %%
# Verificar e tratar valores nulos
print("Valores nulos em 'orders':")
print(orders.isnull().sum())
print("\nValores nulos em 'order_details':")
print(order_details.isnull().sum())
print("\nValores nulos em 'products':")
print(products.isnull().sum())
# Out:
# Valores nulos em 'orders':
# order_id              0
# customer_id           0
# employee_id           0
# order_date            0
# required_date         0
# shipped_date         21
# ship_via              0
# freight               0
# ship_name             0
# ship_address          0
# ship_city             0
# ship_region         507
# ship_postal_code     19
# ship_country          0
# dtype: int64
#
# Valores nulos em 'order_details':
# order_id      0
# product_id    0
# unit_price    0
# quantity      0
# discount      0
# dtype: int64
#
# Valores nulos em 'products':
# product_id           0
# product_name         0
# supplier_id          0
# category_id          0
# quantity_per_unit    0
# unit_price           0
# units_in_stock       0
# units_on_order       0
# reorder_level        0
# discontinued         0
# dtype: int64

# %%
# Tratamento de valores nulos
orders['ship_region'] = orders['ship_region'].fillna('Unknown')
orders['ship_postal_code'] = orders['ship_postal_code'].fillna('Unknown')

# %%
# Verificação de duplicatas
print("Duplicatas em 'orders':")
print(orders.duplicated().sum())
print("\nDuplicatas em 'order_details':")
print(order_details.duplicated().sum())
print("\nDuplicatas em 'products':")
print(products.duplicated().sum())
# Out:
# Duplicatas em 'orders':
# 0
#
# Duplicatas em 'order_details':
# 0
#
# Duplicatas em 'products':
# 0

# %%
# Unir tabelas
order_products = pd.merge(order_details, products, on='product_id')
order_products_orders = pd.merge(order_products, orders, on='order_id')

display(order_products_orders.head())
# Out:
#    order_id  product_id  unit_price_x  quantity  discount                   product_name  supplier_id  category_id quantity_per_unit  unit_price_y  units_in_stock  units_on_order  reorder_level  discontinued customer_id  employee_id order_date required_date shipped_date  ship_via  freight                  ship_name        ship_address ship_city ship_region ship_postal_code ship_country
# 0     10248          11          14.0        12       0.0                 Queso Cabrales            5            4         1 kg pkg.         21.00              22              30             30         False       VINET            5 1996-07-04    1996-08-01   1996-07-16         3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye     Reims     Unknown            51100       France
# 1     10248          42           9.8        10       0.0  Singaporean Hokkien Fried Mee           20            5   32 - 1 kg pkgs.         14.00              26               0              0          True       VINET            5 1996-07-04    1996-08-01   1996-07-16         3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye     Reims     Unknown            51100       France
# 2     10248          72          34.8         5       0.0         Mozzarella di Giovanni           14            4  24 - 200 g pkgs.         34.80              14               0              0         False       VINET            5 1996-07-04    1996-08-01   1996-07-16         3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye     Reims     Unknown            51100       France
# 3     10249          14          18.6         9       0.0                           Tofu            6            7  40 - 100 g pkgs.         23.25              35               0              0         False       TOMSP            6 1996-07-05    1996-08-16   1996-07-10         1    11.61         Toms Spezialitäten       Luisenstr. 48   Münster     Unknown            44087      Germany
# 4     10249          51          42.4        40       0.0          Manjimup Dried Apples           24            7  50 - 300 g pkgs.         53.00              20               0             10         False       TOMSP            6 1996-07-05    1996-08-16   1996-07-10         1    11.61         Toms Spezialitäten       Luisenstr. 48   Münster     Unknown            44087      Germany

# %%
# Calcular faturamento total

order_products_orders['total_price'] = order_products_orders['quantity'] * order_products_orders['unit_price_x'] #cria coluna com total_price

faturamento_total = order_products_orders['total_price'].sum()
print(f'Faturamento Total: {faturamento_total}')

# Faturamento por categoria
faturamento_por_categoria = order_products_orders.groupby('category_id')['total_price'].sum().reset_index()
faturamento_por_categoria = pd.merge(faturamento_por_categoria, categories, on='category_id')
print(faturamento_por_categoria)

# Agrupar por country e somar o faturamento
faturamento_por_regiao = order_products_orders.groupby('ship_country')['total_price'].sum().reset_index()
print(faturamento_por_regiao)
# Out:
# Faturamento Total: 1354458.59
#    category_id  total_price   category_name                                        description picture
# 0            1    286526.95       Beverages        Soft drinks, coffees, teas, beers, and ales      \x
# 1            2    113694.75      Condiments  Sweet and savory sauces, relishes, spreads, an...      \x
# 2            3    177099.10     Confections                Desserts, candies, and sweet breads      \x
# 3            4    251330.50  Dairy Products                                            Cheeses      \x
# 4            5    100726.80  Grains/Cereals                Breads, crackers, pasta, and cereal      \x
# 5            6    178188.80    Meat/Poultry                                     Prepared meats      \x
# 6            7    105268.60         Produce                          Dried fruit and bean curd      \x
# 7            8    141623.09         Seafood                                   Seaweed and fish      \x
#    ship_country  total_price
# 0     Argentina      8119.10
# 1       Austria    139496.63
# 2       Belgium     35134.98
# 3        Brazil    114968.48
# 4        Canada     55334.10
# 5       Denmark     34782.25
# 6       Finland     19778.45
# 7        France     85498.76
# 8       Germany    244640.63
# 9       Ireland     57317.39
# 10        Italy     16705.15
# 11       Mexico     24073.45
# 12       Norway      5735.15
# 13       Poland      3531.95
# 14     Portugal     12468.65
# 15        Spain     19431.89
# 16       Sweden     59523.70
# 17  Switzerland     32919.50
# 18           UK     60616.51
# 19          USA    263566.98
# 20    Venezuela     60814.89

# %%
# Ticket Médio por Cliente
ticket_medio_por_cliente = order_products_orders.groupby('customer_id')['total_price'].mean().reset_index()
ticket_medio_por_cliente.columns = ['customer_id', 'ticket_medio']
print('ticket_medio_por_cliente')
print(ticket_medio_por_cliente)

# Vendas por Funcionario 
vendas_por_funcionario = order_products_orders.groupby('employee_id')['total_price'].sum().reset_index()
vendas_por_funcionario.columns = ['employee_id', 'vendas_por_funcionario']
print('vendas_por_funcionario')
print(vendas_por_funcionario)
# Out:
# ticket_medio_por_cliente
#    customer_id  ticket_medio
# 0        ALFKI    383.016667
# 1        ANATR    140.295000
# 2        ANTON    442.079412
# 3        AROUT    460.216667
# 4        BERGS    518.618269
# 5        BLAUS    231.414286
# 6        BLONP    734.153846
# 7        BOLID    882.966667
# 8        BONAP    542.067045
# 9        BOTTM    645.934286
# 10       BSBEV    276.813636
# 11       CACTU    164.981818
# 12       CENTC     50.400000
# 13       CHOPS    585.740909
# 14       COMMI    381.075000
# 15       CONSH    245.585714
# 16       DRACD    376.321000
# 17       DUMON    179.544444
# 18       EASTC    715.888571
# 19       ERNSH   1110.163529
# 20       FAMIA    233.626316
# 21       FOLIG    729.181250
# 22       FOLKO    723.456667
# 23       FRANK    598.389792
# 24       FRANR    528.693333
# 25       FRANS    154.570000
# 26       FURIB    357.577500
# 27       GALED    104.587500
# 28       GODOS    455.003846
# 29       GOURL    458.012105
# 30       GREAL    895.960455
# 31       GROSR    372.175000
# 32       HANAR   1065.660938
# 33       HILAA    524.701778
# 34       HUNGC    340.355556
# 35       HUNGO   1042.134364
# 36       ISLAT    267.230435
# 37       KOENE    813.993590
# 38       LACOR    181.095455
# 39       LAMAI    331.366129
# 40       LAUGB     65.312500
# 41       LAZYK    178.500000
# 42       LEHMS    545.692821
# 43       LETSS    349.002000
# 44       LILAS    524.266471
# 45       LINOD    511.130000
# 46       LONEP    304.185714
# 47       MAGAA    362.088095
# 48       MAISD    613.563529
# 49       MEREP   1006.371875
# 50       MORGK    458.381818
# 51       NORTS    108.166667
# 52       OCEAN    314.563636
# 53       OLDWO    680.214583
# 54       OTTIK    453.706897
# 55       PERIC    303.014286
# 56       PICCO   1141.736957
# 57       PRINI    531.710000
# 58       QUEDE    290.567917
# 59       QUEEN    755.652500
# 60       QUICK   1366.085930
# 61       RANCH    237.008333
# 62       RATTC    735.857746
# 63       REGGC    343.436364
# 64       RICAR    478.681481
# 65       RICSU    667.773333
# 66       ROMEY    104.806429
# 67       SANTG    358.446875
# 68       SAVEA    997.184397
# 69       SEVES    660.463462
# 70       SIMOB   1209.230000
# 71       SPECD    403.891667
# 72       SPLIR    624.485000
# 73       SUPRD    633.446154
# 74       THEBI    480.142857
# 75       THECR    243.405000
# 76       TOMSP    353.857143
# 77       TORTU    372.832759
# 78       TRADH    562.355385
# 79       TRAIH    174.577778
# 80       VAFFE    536.896774
# 81       VICTE    397.484000
# 82       VINET    148.000000
# 83       WANDK    409.763462
# 84       WARTH    449.110811
# 85       WELLI    341.089474
# 86       WHITC    726.836250
# 87       WILMK    185.961765
# 88       WOLZA    220.746875
# vendas_por_funcionario
#    employee_id  vendas_por_funcionario
# 0            1               202143.71
# 1            2               177749.26
# 2            3               213051.30
# 3            4               250187.45
# 4            5                75567.75
# 5            6                78198.10
# 6            7               141295.99
# 7            8               133301.03
# 8            9                82964.00

# %%
# Taxa de Churn -  calculada com base nos clientes que não fizeram pedidos nos últimos meses

ultimo_pedido = orders.groupby('customer_id')['order_date'].max().reset_index() 

#criada coluna churn que recebe o valor 1 se a data do último pedido for mais antiga 
#do que a data atual menos seis meses, indicando que o cliente não fez pedidos nos últimos seis meses. 
ultimo_pedido['churn'] = (ultimo_pedido['order_date'] < (orders['order_date'].max() - pd.DateOffset(months=6))).astype(int)
 
taxa_churn = ultimo_pedido['churn'].mean() #media coluna churn 
print(f'Taxa de Churn: {taxa_churn}')
# Out:
# Taxa de Churn: 0.056179775280898875

# %%
# visualizando dados


# Salvar os gráficos como imagens
plt.figure(figsize=(10, 6))
sns.barplot(x='category_name', y='total_price', data=faturamento_por_categoria)
plt.title('Faturamento por Categoria de Produto')
plt.xlabel('Categoria')
plt.ylabel('Faturamento')
plt.xticks(rotation=45)
plt.savefig('faturamento_por_categoria.png')  # Salvar o gráfico como uma imagem

plt.figure(figsize=(10, 6))
sns.barplot(x='ship_country', y='total_price', data=faturamento_por_regiao)
plt.title('Faturamento por Região')
plt.xlabel('Região')
plt.ylabel('Faturamento')
plt.xticks(rotation=45)
plt.savefig('faturamento_por_regiao.png')  # Salvar o gráfico como uma imagem

plt.figure(figsize=(10, 6))
sns.histplot(ticket_medio_por_cliente['ticket_medio'], bins=30)
plt.title('Distribuição do Ticket Médio por Cliente')
plt.xlabel('Ticket Médio')
plt.ylabel('Frequência')
plt.savefig('ticket_medio_por_cliente.png')  # Salvar o gráfico como uma imagem

plt.figure(figsize=(8, 8))
plt.pie(vendas_por_funcionario['vendas_por_funcionario'], labels=vendas_por_funcionario['employee_id'], autopct='%1.1f%%')
plt.title('Total de Vendas por Funcionário')
plt.savefig('vendas_por_funcionario.png')  # Salvar o gráfico como uma imagem

# %%
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image, PageBreak
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.enums import TA_CENTER

# Criar um documento PDF
pdf_filename = "relatorio_northwind.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter)
styles = getSampleStyleSheet()

# Estilos personalizados
title_style = ParagraphStyle(
    'Title',
    parent=styles['Title'],
    fontSize=18,
    leading=22,
    alignment=TA_CENTER,
    spaceAfter=20
)

subtitle_style = ParagraphStyle(
    'Subtitle',
    parent=styles['Heading2'],
    fontSize=14,
    leading=18,
    spaceAfter=10
)

normal_style = styles['BodyText']
normal_style.spaceAfter = 12

# Lista para armazenar o conteúdo do PDF
content = []

# Adicionar título
content.append(Paragraph("Relatório Northwind", title_style))
content.append(Spacer(1, 12))

# Adicionar gráficos ao PDF com subtítulos
content.append(Paragraph("Faturamento por Categoria de Produto", subtitle_style))
content.append(Image('faturamento_por_categoria.png', width=500, height=300))
content.append(Spacer(1, 12))

content.append(Paragraph("Faturamento por Região", subtitle_style))
content.append(Image('faturamento_por_regiao.png', width=500, height=300))
content.append(Spacer(1, 12))

content.append(Paragraph("Distribuição do Ticket Médio por Cliente", subtitle_style))
content.append(Image('ticket_medio_por_cliente.png', width=500, height=300))
content.append(Spacer(1, 12))

content.append(Paragraph("Vendas por Funcionário", subtitle_style))
content.append(Image('vendas_por_funcionario.png', width=500, height=500))
content.append(Spacer(1, 12))

# Adicionar a taxa de churn ao PDF
churn_text = "A taxa de Churn: {:.2%}, implica que a empresa precisa adquirir novos clientes continuamente para manter o mesmo nível de receita.".format(taxa_churn)
churn_paragraph = Paragraph(churn_text, style=normal_style)
content.append(churn_paragraph)

# Adicionar texto de interpretação de análises
analises_text1 = "As bebidas, Produtos de Confeitaria (Confections) e Produtos à Base de Carne (Meat/Poultry) são as categorias de produto mais lucrativas, e estratégias para aumentar ainda mais essa receita podem ser vantajosas."
analises_paragraph1 = Paragraph(analises_text1, style=normal_style)
content.append(analises_paragraph1)

analises_text2 = "Os países com mais vendas são Alemanha, USA, Áustria e Brasil. Já os com menos vendas são Polônia, Noruega e Argentina."
analises_paragraph2 = Paragraph(analises_text2, style=normal_style)
content.append(analises_paragraph2)

analises_text3 = ("O valor de compra dos clientes apresenta um pico médio entre 300 e 500. "
                  "Há uma diminuição gradual na frequência conforme o ticket médio aumenta além de 600. "
                  "Logo, há um potencial para aumentar o ticket médio dos clientes que estão na faixa de 200 a 400, "
                  "incentivando maiores compras através de promoções ou pacotes de produtos. "
                  "E para valores maiores que 600, representam uma oportunidade para personalização de ofertas e serviços VIP, "
                  "visando aumentar a satisfação e a retenção desses clientes de alto valor e também analisar o que os leva a comprar mais.")
analises_paragraph3 = Paragraph(analises_text3, style=normal_style)
content.append(analises_paragraph3)

analises_text4 = "Os funcionários com id 4 e id 3 são responsáveis pela maior parte das vendas, talvez seja válido uma bonificação."
analises_paragraph4 = Paragraph(analises_text4, style=normal_style)
content.append(analises_paragraph4)

# Adicionar quebra de página se necessário
content.append(PageBreak())

# Construir o PDF
doc.build(content)
